# %%
# Variables
x = 4
y = 5
x + y
# Out:
# 9

# %%
# Data Types: Strings
name = "Kevin"

# %%
city = "Austin"

# %%
state = "Texas"

# %%
citystate = state + city

# %%
# Data Types
# What are Operators?
# Arithmetic Operators: + - / * ** // %
x = 2
y = 3
z = x % y

# %%
z
# Out:
# 2

# %%
# Assignment: = += -= *= /=
x = 2

# %%
x
# Out:
# 2

# %%
x = 2
x = x +10
# Alternate way:
x +=10

# %%
# Comparison: == != > < >= <=
x = 2
y = 3
x == y # == means "is equal to?"
# Out:
# False

# %%
x != y # is not equal to?
# Out:
# True

# %%
x > y
# Out:
# False

# %%
# Logical: and or not

# %%
# Expression: some type of combinations of variables to go a certain thing
# Functions: Allows us to do things
print('hello world')
# Out:
# hello world

# %%
greeting = 'Hello, world!'

# %%
print(greeting)
# Out:
# Hello, world!

# %%
# Arguments are things passed through functionsm
# Create a program to welcome the user
name = input("Hello, what's your name")
print("Hello,", name)
# Out:
# Hello, what's your name 'Kevin'
# Hello, 'Kevin'

# %%
print("Hello,", input("Hello, what's your name?"))
# Out:
# Hello, what's your name? 'Kevin'
# Hello, 'Kevin'

# %%
# type ()
x = 4
y = 5
name = "Bill"

# %%
x = "4"
x = 4

# %%
print(x)
# Out:
# 4

# %%
type(x)
# Out:
# int

# %%
print(type(x)) # tells us waht data type an argument is
# Out:
# <class 'int'>

# %%
# Casting: Converting one data type to a different data type
# Convert str to an int
x = "4"
type(int(x))
# Out:
# int

# %%
x = "4"
type(str(x))
# Out:
# str

# %%
bool(4)
# Out:
# True

# %%
x = "4"
type(float(x))
# Out:
# float

# %%
# Complex Data types
# Data collections allow us to store mutliples of the basic data types
# 1: Lists
# collections of many different data types in a list
example_list = []

# %%
print(example_list)
# Out:
# []

# %%
# Create a list of Ice Cream Flavors
example_list = ['Vanilla', 'Chocolate', 'Rocky Road', 'Cookie Dough']

# %%
print(example_list)
# Out:
# ['Vanilla', 'Chocolate', 'Rocky Road', 'Cookie Dough']

# %%
# Create a List of Data about yourslef
personal_info = ['Kevin', 31, 'Data Analytics', 'Data Science', False]
name = 'Kevin'
age = 31
enrolled_in = 'Data Analytics'
area_of_interest = 'Data Science'
in_education = False

# %%
# Dictionary
example_dictionary = {} # curly brackets

# %%
print(example_dictionary)
# Out:
# {}

# %%
example_dictionary = 
{
    "name" : 'Kevin'
    "age" = 31
    "enrolled_in" = 'Data Analytics'
    "in_education" = False
}
